# %%
library(tidyverse)
library(repr)
options(repr.matrix.max.rows = 10)

wine_data_og <- read_csv("Wine_quality.csv", col_names = TRUE)
colnames(wine_data)<- c("fixed_acidity", "volatile_acidity", "citric_acid", "residual_sugar", "chlorides", "free_sulfur_dioxide", "total_sulpher_dioxide","density", "pH", "sulphates", "alcohol", "quality", "id")


mutate(quality=as_factor(quality))
wine_data
# Out:
# Parsed with column specification:
# cols(
#   `fixed acidity` = col_double(),
#   `volatile acidity` = col_double(),
#   `citric acid` = col_double(),
#   `residual sugar` = col_double(),
#   chlorides = col_double(),
#   `free sulfur dioxide` = col_double(),
#   `total sulfur dioxide` = col_double(),
#   density = col_double(),
#   pH = col_double(),
#   sulphates = col_double(),
#   alcohol = col_double(),
#   quality = col_double(),
#   Id = col_double()
# )
# Error in UseMethod("mutate_"): no applicable method for 'mutate_' applied to an object of class "character"
# Traceback:
#
# 1. c("fixed_acidity", "volatile_acidity", "citric_acid", "residual_sugar",
#  .     "chlorides", "free_sulfur_dioxide", "total_sulpher_dioxide",
#  .     "density", "pH", "sulphates", "alcohol", "quality", "id") %>%
#  .     mutate(quality = as_factor(quality))
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# ...

# %%
wine_data <- mutate(quality=as_factor(quality))
wine_data

# %%
plot1 <- wine_data %>%
ggplot(aes(x=fixed_acidity, y=residual_sugar, color=quality))+
    geom_point()
plot1
# Out:
# plot without title

# %%
plot2 <- wine_data %>%
ggplot(aes(x=citric_acid, y=residual_sugar, color=quality))+
    geom_point()
plot2
# Out:
# plot without title

# %%
plot3 <- wine_data %>%
ggplot(aes(x=volatile_acidity, y=chlorides, color=quality))+
    geom_point()
plot3
# Out:
# plot without title

# %%
plot4 <- wine_data %>%
ggplot(aes(x=pH, y=quality, color=))+
    geom_point()
plot4
# Out:
# plot without title
